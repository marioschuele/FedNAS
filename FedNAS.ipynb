# %%
# !pip install --upgrade wandb
# !pip install mpi4py
# !pip install torchsummaryX

# %%
# !wandb login
#wandb API: 37feacd21286db2904d6baf9275dc9b32df5b2c5

# %%
# !nvidia-smi

# %%
# %cd /content/drive/MyDrive/FedNAS-master/
# Out:
# /content/drive/MyDrive/FedNAS-master

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download yuweisunut/sidd-segmented-intrusion-detection-dataset
# !unzip sidd-segmented-intrusion-detection-dataset

# %%
# !sudo useradd non_root_user

# %%
# !sudo passwd non_root_user

# %%
# !sudo chown -R non_root_user:non_root_user ./FedNAS
# !sudo chmod -R 755 ./FedNAS
#!sudo chown -R non_root_user:non_root_user ../
#!sudo chmod -R 755 ../
# !sudo chown -R non_root_user:non_root_user ./wandb
# !sudo chmod -R 755 ./wandb

# %%
# !sh mpirun -np 16 -hostfile ./mpi_host_file python3 ./main.py
# Out:
# INFO:root:#############process ID = 0, host name = 23d856aff0d8########, process ID = 27920, process Name = psutil.Process(pid=27920, name='Federated Learning:0', status='running', started='13:09:31')
# INFO:root:rank = 0, size = 1
# ******Get to rank check
# This is rank 0
# Startet den Server
# wandb: WARNING Path /content/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path /content/wandb/ wasn't writable, using system temp directory
# wandb: WARNING Path /content/wandb/ wasn't writable, using system temp directory
# wandb: ERROR api_key not configured (no-tty). call wandb.login(key=[your_api_key])
# Traceback (most recent call last):
#   File "/content/./FedNAS/main.py", line 227, in <module>
#     init_server(args, comm, rank, size, round_num)
#   File "/content/./FedNAS/main.py", line 93, in init_server
#     wandb.init(
#   File "/usr/local/lib/python3.9/dist-packages/wandb/sdk/wandb_init.py", line 1140, in init
#     wi.setup(kwargs)
# ...

# %%
# !hostname
# !id -gn non_root_user
# Out:
# 23d856aff0d8
# non_root_user

# %%
# !ls
# Out:
# bin	 dev   lib32   mnt			 python-apt  srv    usr
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  root	     sys    var
# content  home  libx32  opt			 run	     tmp
# datalab  lib   media   proc			 sbin	     tools

# %%
# search
# !python ./FedNAS/main.py #1 darts hetero 5 5 5
# Out:
# INFO:root:#############process ID = 0, host name = 23d856aff0d8########, process ID = 11822, process Name = psutil.Process(pid=11822, name='Federated Learning:0', status='running', started='12:08:21')
# INFO:root:rank = 0, size = 1
# ******Get to rank check
# This is rank 0
# Startet den Server
# wandb: Currently logged in as: mario-schuele (team-mario). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.14.0
# wandb: Run data is saved locally in /content/wandb/run-20230328_120827-5phgkkhz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run FedNAS(d)heteror30-e1-lr0.025
# wandb: ⭐️ View project at https://wandb.ai/team-mario/federated_nas
# wandb: 🚀 View run at https://wandb.ai/team-mario/federated_nas/runs/5phgkkhz
# INFO:root:load dataset
# INFO:root:Client structure identified
# INFO:root:Client structure identified
# INFO:root:Client structure identified
# INFO:root:Client structure identified
# ...

# %%
directory = 'SIDD'
uid = 0
imgs = {}

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
import os

# %%
for i, client in enumerate(os.listdir(directory)):
        curr_path = f'{directory}/{client}/pcap'
        logging.info("Client %s structure identified", i)

        """
        for subdir in os.listdir(curr_path):
          curr_path = f'{directory}/{client}/pcap/{subdir}/dataset'
          curr_type = subdir[-1:]
   
          for dayscen in os.listdir(curr_path):
            curr_path = f'{directory}/{client}/pcap/{subdir}/dataset/{dayscen}'
            logging.info("Iterate days: %s", dayscen)
            for img in os.listdir(curr_path):
              #logging.info("Add images to df")
              if dayscen == 'benign':
                imgs[uid] = {'id': uid, 'label': str(0), 'fn': img, 'path': curr_path + '/' + img}
              elif dayscen == 'malicious':
                imgs[uid] = {'id': uid, 'label': str(curr_type), 'fn': img, 'path': curr_path + '/' + img}
          uid +=1
          """
